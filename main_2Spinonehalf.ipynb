# %%
# Import Simulation Class
from ESR_STM_SpinSimulation import SpinSys
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Define the Spin System
Spins=[0.5,0.5]
S = SpinSys(Spins)
S.calcSpinOperators()
S.B=[0,0,0.5]
S.BTip=[1e-7,0,0.0]
S.tip='f'
S.TipPolarization=[0,0,0]
S.T=1
S.Jvector=np.array([[1*S.GHztomeVConversion,1*S.GHztomeVConversion,1*S.GHztomeVConversion]])
S.AtomPositions=np.array([[0,0,0],[2,2,0]])
S.DipoleBool=[True]
S.V_DC=-10

# %%
# Simulation

#S.calcEigEnergies();
#S.showEigenMatrix();
#S.calcESR_Benjamin(norm=False,lw=0.05,plot=1,AllowPumping=0);
S.plotESRTipfieldsweep(N_B=500,N_Freq=500,BTipLimits=[-0.05,0.05],lw=0.1,norm=1,AllowPumping=0)
#S.print_parameters()
# Out:
# c:\Users\paulg\Desktop\ESR-Simulation\ESR_STM_SpinSimulation.py:650: RuntimeWarning: overflow encountered in exp
#   else:
