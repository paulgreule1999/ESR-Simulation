# %%
# Import Simulation Class
import sys
sys.path.append('..')  # Add parent directory to the system path
from ESR_STM_SpinSimulation import SpinSys
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Define the Spin System
Spins=[0.5,0.5]
S = SpinSys(Spins)
S.calcSpinOperators()
S.B=[0,0,0.5]
S.BTip=[1e-7,0,0]
S.tip='f'
S.TipPolarization=[0,0,0]
S.T=1
S.Jvector=np.array([[1*S.GHztomeVConversion,1*S.GHztomeVConversion,1*S.GHztomeVConversion]])
print(S.Jvector)
S.AtomPositions=np.array([[0,0,0],[2,2,0]])
S.DipoleBool=[True]
S.V_DC=-100
# Out:
# [[0.00413567 0.00413567 0.00413567]]

# %%
# Simulation

S.calcEigEnergies();
S.showEigenMatrix('p');
#S.calcESR_Benjamin(norm=False,lw=0.05,plot=1,AllowPumping=0);
S.plotESRTipfieldsweep(N_B=500,N_Freq=500,BTipLimits=[-0.1,0.1],lw=0.1,norm=1,AllowPumping=0)
#S.plotEnergyVsSz()
#S.print_parameters()
#print(S.eigVectors)
#print(S.states)
#print(S.basisStates)
