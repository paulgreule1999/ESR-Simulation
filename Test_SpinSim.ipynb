# %%
from ESR_STM_SpinSimulation import SpinSys
import numpy as np
Spins=[0.5,0.5]
S = SpinSys(Spins)
S.calcSpinOperators()
S.B=[0,0,0.5]
S.BTip=[1e-9,0,0.002]
S.tip='a'
S.Dvector=[0,0]
S.Jvector=np.array([[0.1*S.GHztomeVConversion,0.1*S.GHztomeVConversion,0.1*S.GHztomeVConversion]])
S.AtomPositions=np.array([[0,0,0],[1,1,0]])
S.DipoleBool=[False]
S.calcEigEnergies()
S.showEigenMatrix()
#print(S.E_All)
#print(S.basisStates)
#S.calcSpinOperators()

# %%
import numpy as np
A=np.array([[1,2,3,4], [4,5,6,4],[4,5,6,4],[4,5,6,4]])
B=np.zeros((2,4,4))
B[0,:,:]=A
#print(type(S.dimensionOfMatrix))
print(np.eye(len(np.arange(-0.5,0.5+1))))
print(A**2)
# Out:
# [[1. 0.]
#  [0. 1.]]
# [[ 1  4  9 16]
#  [16 25 36 16]
#  [16 25 36 16]
#  [16 25 36 16]]
